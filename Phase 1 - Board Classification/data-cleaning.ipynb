# %% [markdown]
# ## Data Preprocessing

# %%
#convert images to jpg
import rawpy
import imageio
import os

input_path = "2025-04-17"
output_path = "PCB Images"

os.makedirs(output_path, exist_ok=True)

#convert each CR2 file to png
for file in os.listdir(input_path):
    if file.endswith(".CR2"):
        print("Converting", file)
        cr2_path = os.path.join(input_path, file)
        output_folder = os.path.join(output_path, os.path.splitext(file)[0] + ".png")
        with rawpy.imread(cr2_path) as raw:
            rgb = raw.postprocess() # Postprocess the image into RGB
        
        imageio.imwrite(output_folder, rgb) #save as PNG
# Out:
# Converting _MG_1652.CR2
# Converting _MG_1653.CR2
# Converting _MG_1654.CR2
# Converting _MG_1655.CR2
# Converting _MG_1656.CR2
# Converting _MG_1657.CR2
# Converting _MG_1658.CR2
# Converting _MG_1659.CR2
# Converting _MG_1660.CR2
# Converting _MG_1661.CR2
# Converting _MG_1662.CR2
# Converting _MG_1663.CR2
# Converting _MG_1664.CR2
# Converting _MG_1665.CR2
# Converting _MG_1666.CR2
# Converting _MG_1667.CR2
# Converting _MG_1668.CR2
# Converting _MG_1669.CR2
# Converting _MG_1670.CR2
# Converting _MG_1671.CR2
# Converting _MG_1672.CR2
# Converting _MG_1673.CR2
# Converting _MG_1674.CR2
# Converting _MG_1675.CR2
# Converting _MG_1676.CR2
# Converting _MG_1677.CR2
# Converting _MG_1678.CR2
# Converting _MG_1679.CR2
# Converting _MG_1680.CR2
# Converting _MG_1681.CR2
# Converting _MG_1682.CR2
# Converting _MG_1683.CR2
# Converting _MG_1684.CR2
# Converting _MG_1685.CR2
# Converting _MG_1686.CR2
# Converting _MG_1687.CR2
# Converting _MG_1688.CR2
# Converting _MG_1689.CR2
# Converting _MG_1690.CR2
# Converting _MG_1691.CR2
# Converting _MG_1692.CR2
# Converting _MG_1693.CR2
# Converting _MG_1694.CR2
# Converting _MG_1695.CR2
# Converting _MG_1696.CR2
# Converting _MG_1697.CR2
# Converting _MG_1698.CR2
# Converting _MG_1699.CR2
# Converting _MG_1700.CR2
# Converting _MG_1701.CR2
# Converting _MG_1702.CR2
# Converting _MG_1703.CR2
# Converting _MG_1704.CR2
# Converting _MG_1705.CR2
# Converting _MG_1706.CR2
# Converting _MG_1707.CR2
# Converting _MG_1708.CR2
# Converting _MG_1709.CR2
# Converting _MG_1710.CR2
# Converting _MG_1711.CR2
# Converting _MG_1712.CR2
# Converting _MG_1713.CR2
# Converting _MG_1714.CR2
# Converting _MG_1715.CR2
# Converting _MG_1716.CR2
# Converting _MG_1717.CR2
# Converting _MG_1718.CR2
# Converting _MG_1719.CR2
# Converting _MG_1720.CR2
# Converting _MG_1721.CR2
# Converting _MG_1722.CR2
# Converting _MG_1723.CR2
# Converting _MG_1724.CR2
# Converting _MG_1725.CR2
# Converting _MG_1726.CR2
# Converting _MG_1727.CR2
# Converting _MG_1728.CR2
# Converting _MG_1729.CR2
# Converting _MG_1730.CR2
# Converting _MG_1731.CR2
# Converting _MG_1732.CR2
# Converting _MG_1733.CR2
# Converting _MG_1734.CR2
# Converting _MG_1735.CR2
# Converting _MG_1736.CR2
# Converting _MG_1737.CR2
# Converting _MG_1738.CR2
# Converting _MG_1739.CR2
# Converting _MG_1740.CR2
# Converting _MG_1741.CR2
# Converting _MG_1742.CR2
# Converting _MG_1743.CR2
# Converting _MG_1744.CR2
# Converting _MG_1745.CR2
# Converting _MG_1746.CR2
# Converting _MG_1747.CR2
# Converting _MG_1748.CR2
# Converting _MG_1749.CR2
# Converting _MG_1750.CR2
# Converting _MG_1751.CR2
# Converting _MG_1752.CR2
# Converting _MG_1753.CR2
# Converting _MG_1754.CR2
# Converting _MG_1755.CR2
# Converting _MG_1756.CR2
# Converting _MG_1757.CR2
# Converting _MG_1758.CR2
# Converting _MG_1759.CR2
# Converting _MG_1760.CR2
# Converting _MG_1761.CR2
# Converting _MG_1762.CR2
# Converting _MG_1763.CR2
# Converting _MG_1764.CR2
# Converting _MG_1765.CR2
# Converting _MG_1766.CR2
# Converting _MG_1767.CR2
# Converting _MG_1768.CR2
# Converting _MG_1769.CR2
# Converting _MG_1770.CR2
# Converting _MG_1771.CR2
# Converting _MG_1772.CR2
# Converting _MG_1773.CR2
# Converting _MG_1774.CR2
# Converting _MG_1775.CR2
# Converting _MG_1776.CR2
# Converting _MG_1777.CR2
# Converting _MG_1778.CR2
# Converting _MG_1779.CR2
# Converting _MG_1780.CR2
# Converting _MG_1781.CR2
# Converting _MG_1782.CR2
# Converting _MG_1784.CR2
# Converting _MG_1785.CR2
# Converting _MG_1786.CR2
# Converting _MG_1787.CR2
# Converting _MG_1788.CR2
# Converting _MG_1789.CR2
# Converting _MG_1790.CR2
# Converting _MG_1791.CR2
# Converting _MG_1792.CR2
# Converting _MG_1793.CR2

# %%
import cv2

def check_image_dimensions(image_path):
    # Read the image
    image = cv2.imread(image_path)
    if image is None:
        raise ValueError("Image not found or unable to read")

    # Get the dimensions of the image
    height, width, channels = image.shape

    # Print the dimensions
    print(f"Width: {width}, Height: {height}, Channels: {channels}")

# Example usage
check_image_dimensions('PCB Images/nodefects_54.png')
# Out:
# Width: 5202, Height: 3464, Channels: 3

# %% [markdown]
# # Crop images and save to folder so that its focused on PCB only

# %%
import cv2

def crop_image(image, x, y, width, height):
    # Crop the image to the specified size
    cropped_image = image[y:y+height, x:x+width]
    return cropped_image

def resize_image(image, max_width=800, max_height=600):
    height, width = image.shape[:2]
    scaling_factor = min(max_width / width, max_height / height)
    new_size = (int(width * scaling_factor), int(height * scaling_factor))
    return cv2.resize(image, new_size, interpolation=cv2.INTER_AREA)

image = cv2.imread('PCB Images/nodefects_54.png')
# Example usage
cropped_image = crop_image(image, 800, 500, 3500, 2300)

# Resize the cropped image for display
resized_image = resize_image(cropped_image)

# Save resized cropped image
cv2.imwrite('resized_cropped_image2.png', resized_image)

# Display the resized cropped image
cv2.imshow('Cropped Image', resized_image)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
import cv2
import numpy as np

# Load the image
image_path = "PCB Images/nodefects_2.png"
image = cv2.imread(image_path)

# Resize function to maintain aspect ratio
def resize_image(image, max_width=800, max_height=600):
    height, width = image.shape[:2]
    scaling_factor = min(max_width / width, max_height / height)
    new_size = (int(width * scaling_factor), int(height * scaling_factor))
    return cv2.resize(image, new_size, interpolation=cv2.INTER_AREA)

# Convert to grayscale
gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

# Apply Gaussian Blur to reduce noise
blurred = cv2.GaussianBlur(gray, (5, 5), 0)

# Apply Canny edge detection
edges = cv2.Canny(blurred, 50, 150)

# Find contours
contours, _ = cv2.findContours(edges, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)

# Draw contours on the original image
cv2.drawContours(image, contours, -1, (0, 255, 0), 5)  # Green outline

# Resize image for display
resized_image = resize_image(image)

# Display the result
cv2.imshow("Detected PCB Outline", resized_image)
cv2.waitKey(0)  # Wait for a key press to close
cv2.destroyAllWindows()
